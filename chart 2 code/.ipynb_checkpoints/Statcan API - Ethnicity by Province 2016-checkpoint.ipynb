# %%
import requests
import pprint

# %% [markdown]
# #1 The first step is to look for relevant table. In this case it is actually faster to paste the URL to chrome and do search function.
# #URL is 'https://www150.statcan.gc.ca/t1/wds/rest/getAllCubesListLite'
#
# #2. We found that the table we want is "Average satisfaction with life and with selected domains of life by age group and sex"
# #3. What's important is the productId, which is be used for downloading the CSV.
# #4. Product id is 13100106
# #5. The next thing to do is to call the download method.
# #https://www12.statcan.gc.ca/wds-sdw/cpr2016-eng.cfm

# %%
#Search the URL for all title
url = "https://www150.statcan.gc.ca/t1/wds/rest/getAllCubesListLite"
response = requests.get(url)
table = response.json()
print(table)
# Out:
# [{'productId': 10100001, 'cansimId': '183-0021', 'cubeTitleEn': 'Federal public sector employment reconciliation of Treasury Board of Canada Secretariat, Public Service Commission of Canada and Statistics Canada statistical universes, as at December 31', 'cubeTitleFr': 'Emploi du secteur public fédéral rapprochement des univers statistiques du Secrétariat du Conseil du Trésor du Canada, de la Commission de la fonction publique du Canada et de Statistique Canada, au 31 décembre', 'cubeStartDate': '1999-01-01', 'cubeEndDate': '2011-01-01', 'releaseTime': '2012-08-01T12:30', 'archived': '1', 'subjectCode': ['10'], 'surveyCode': ['1713'], 'frequencyCode': 12, 'corrections': []}, {'productId': 10100002, 'cansimId': '191-0002', 'cubeTitleEn': 'Central government debt', 'cubeTitleFr': 'Dette du gouvernement central', 'cubeStartDate': '2009-04-01', 'cubeEndDate': '2020-06-01', 'releaseTime': '2020-09-03T12:30', 'archived': '2', 'subjectCode': ['10'], 'surveyCode': ['7514'], 'frequencyCode': 6, 'corrections': []}, {'productId': 10100003, 'cansimId': '176-0079', 'cubeTitleEn': 'Capital markets activities, gross new issues, retirements and net new issues, par value, Bank of Canada', 'cubeTitleFr': 'Activités des marchés de capitaux : émissions brutes, remboursements et émissions nettes de titres, valeur nominale, Banque du Canada', 'cubeStartDate': '1975-01-01', 'cubeEndDate': '2020-07-01', 'releaseTime': '2020-08-31T12:30', 'archived': '2', 'subjectCode': ['10'], 'surveyCode': ['7502'], 'frequencyCode': 6, 'corrections': []}, {'productId': 10100004, 'cansimId': '176-0013', 'cubeTitleEn': 'Chartered banks, total claims and liabilities booked worldwide vis-à-vis non-residents, Bank of Canada', 'cubeTitleFr': 'Banques à charte, ensembles des créances et engagements comptabilisés dans le monde au nom de non-résidents, Banque du Canada', 'cubeStartDate': '1978-04-01', 'cubeEndDate': '2020-04-01', 'releaseTime': '2020-09-15T12:30', 'archived': '2', 'subjectCode': ['10'], 'surveyCode': ['7502'], 'frequencyCode': 9, 'corrections': []}, {'productId': 10100005, 'cansimId': '385-0041', 'cubeTitleEn': 'Canadian Classification of Functions of Government (CCOFOG) by consolidated government component', 'cubeTitleFr': 'Classification canadienne des fonctions des administrations publiques (CCFAP) par composante des administrations publiques consolidées', 'cubeStartDate': '2008-01-01', 'cubeEndDate': '2018-01-01', 'releaseTime': '2019-11-27T13:30', 'archived': '2', 'subjectCode': ['10'], 'surveyCode': ['5218'], 'frequencyCode': 12, 'corrections': [{'correctionDate': '2019-02-14T05:00:00Z', 'correctionNoteEn': '<p>On February 14, 2019, the data from 2008 to 2017 have been corrected for the Canadian Classification of Functions of Government (CCOFOG) category “Defence not elsewhere classified [7024, 7025]”.<br><br></p>', 'correctionNoteFr': '<p>Le 14 février 2019, les données de 2008 à 2017 ont été corrigées pour la catégorie « Défense non classés ailleurs [7024, 7025] » de la Classification canadienne des fonctions des administrations publiques (CCFAP).<br><br></p>'}]}, {'productId': 10100006, 'cansimId': '176-0091', 'cubeTitleEn': 'Funds advanced, outstanding balances, and interest rates for new and existing lending, Bank of Canada', 'cubeTitleFr': "Avances de fonds, encours des prêts, et taux d'intérêt pour prêts nouveaux et existants, Banque du Canada", 'cubeStartDate': '2013-01-01', 'cubeEndDate': '2020-06-01', 'releaseTime': '2020-08-31T12:30', 'archived': '2', 'subjectCode': ['10'], 'surveyCode': ['7502'], 'frequencyCode': 6, 'corrections': []}, {'productId': 10100007, 'cansimId': '176-0082', 'cubeTitleEn': 'Net new issues of bonds and equities by corporations and federal government enterprises: Industrial classification, Bank of Canada', 'cubeTitleFr': "Émissions nettes d'obligations et d'actions des sociétés et des entreprises publiques fédérales : Classification des industries, Banque du Canada", 'cubeStartDate': '1975-03-01', 'cubeEndDate': '2020 ...

# %%
#Apply the GetFullTable Method
product_id = 13100106
download_path = f"https://www150.statcan.gc.ca/t1/wds/rest/getFullTableDownloadCSV/{product_id}/en"
response = requests.get(download_path)
table = response.json()
print(table)
